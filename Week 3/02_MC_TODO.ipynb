# %% [markdown]
# **Week 3:**
# ## Monte Carlo methods
# - On-policy First-visit MC
# - Off-policy with importance sampling

# %%
import gym
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from collections import defaultdict

# %% [markdown]
# ## Frozen Lake Problem
# ### Part I: On-policy

# %%
env = gym.make('FrozenLake-v1', is_slippery=False)
# env = gym.make("CliffWalking-v0")

# MC parameters
epsilon = 0.1
gamma = 0.9
num_episodes = 80000
max_steps = 200

# %% [markdown]
# #### MC Prediction
# <img src="sut_5_1_mcPred.png" alt="MC Prediction"/>

# %% [markdown]
# #### MC Control
# <img src="sut_5_4_mcCtrl.png" alt="MC Control"/>

# %%
# Function to choose action using epsilon-greedy policy
def epsilon_greedy(policy, state, eps=0.1):
    if np.random.uniform(0, 1) < eps:
        return env.action_space.sample()
    else:
        return policy[state]

def generate_episode(env, policy):
    # TODO
        # Use the following functions:
        # env.reset()
        # epsilon_greedy(policy, s)
        # s, r, done, _, _ = env.step(a)
    
    # we want to return:
    # states  = [s(0), s(1), ..., s(T-1), s(T)]
    # actions = [a(0), a(1), ..., a(T-1),     ]
    # rewards = [   0, R(1), ..., R(T-1), R(T)]

    raise NotImplementedError

def MC_onPol():
    # Initialize an arbirtary, random policy
    policy = {}
    for s in range(env.observation_space.n):
        policy[s] = np.random.choice(env.action_space.n)

    # Initialize Q(s,a) and returns...
    # TODO

    # Repeat until convergence
    # TODO
        # for i in range(num_episodes):
        # states, actions, rewards = generate_episode(env, policy)
        # states_actions = list(zip(states, actions)) # List of state-action pairs
        # for t in range(T - 2, -1, -1):
        # if (states[t], actions[t]) not in states_actions[:t]: # First-Visit Check (if we have already seen (s, a))
    
    raise NotImplementedError

# %%
print('On-policy:')
# MC_onPol()
# Out:
# On-policy:
# Episode: 0
# C:\Users\Victus\anaconda3\Lib\site-packages\gym\utils\passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# Episode: 16000
# Episode: 32000
# Episode: 48000
# Episode: 64000

# %% [markdown]
# **Visualization:**

# %% [markdown]
# **Find V:**

# %% [markdown]
# **Visualize Value Function**

# %% [markdown]
# **Visualize State Counts**

# %% [markdown]
# ### Part II: Off-policy
# <img src="sut_5_7_offMC.png" alt="Off-policy MC"/>

# %%
def MC_offPol():
    raise NotImplementedError

# %%
print('Off-policy:')
# MC_offPol()
# Out:
# On-policy:
# Episode:  0
# Episode:  16000
# Episode:  32000
# Episode:  48000
# Episode:  64000

# %% [markdown]
# **Visualization:**

# %% [markdown]
# **Find V:**
